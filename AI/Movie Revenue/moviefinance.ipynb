# %% [markdown]
# # Introduction
#
# Do higher film budgets lead to more box office revenue? Let's find out if there's a relationship using the movie budgets and financial performance data that I've scraped from [the-numbers.com](https://www.the-numbers.com/movie/budgets) on **May 1st, 2018**.
#
# <img src=https://i.imgur.com/kq7hrEh.png>

# %% [markdown]
# # Import Statements

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.linear_model import LinearRegression

# %% [markdown]
# # Notebook Presentation

# %%
pd.options.display.float_format = '{:,.2f}'.format

from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# %% [markdown]
# # Read the Data

# %%
data = pd.read_csv('cost_revenue_dirty.csv')

# %% [markdown]
# # Explore and Clean the Data

# %% [markdown]
# **Challenge**: Answer these questions about the dataset:
# 1. How many rows and columns does the dataset contain?
# 2. Are there any NaN values present?
# 3. Are there any duplicate rows?
# 4. What are the data types of the columns?

# %%
data
# Out:
#       Rank Release_Date                     Movie_Title USD_Production_Budget  \
# 0     5293     8/2/1915           The Birth of a Nation              $110,000
# 1     5140     5/9/1916                     Intolerance              $385,907
# 2     5230   12/24/1916    20,000 Leagues Under the Sea              $200,000
# 3     5299    9/17/1920  Over the Hill to the Poorhouse              $100,000
# 4     5222     1/1/1925                  The Big Parade              $245,000
# ...    ...          ...                             ...                   ...
# 5386  2950    10/8/2018                             Meg           $15,000,000
# 5387   126   12/18/2018                         Aquaman          $160,000,000
# 5388    96   12/31/2020                     Singularity          $175,000,000
# 5389  1119   12/31/2020          Hannibal the Conqueror           $50,000,000
# 5390  2517   12/31/2020  Story of Bonnie and Clyde, The           $20,000,000
#
# ...

# %%
print(data.shape)
print(f'There are {data.shape[0]} rows and {data.shape[1]} columns')
# Out:
# (5391, 6)
# There are 5391 rows and 6 columns

# %%
print(f'Are there any NAN?\n{data.isna().values.any()}')
data.isna()
# Out:
# Are there any NAN?
# False
#        Rank  Release_Date  Movie_Title  USD_Production_Budget  \
# 0     False         False        False                  False
# 1     False         False        False                  False
# 2     False         False        False                  False
# 3     False         False        False                  False
# 4     False         False        False                  False
# ...     ...           ...          ...                    ...
# 5386  False         False        False                  False
# 5387  False         False        False                  False
# 5388  False         False        False                  False
# 5389  False         False        False                  False
# 5390  False         False        False                  False
#
#       USD_Worldwide_Gross  USD_Domestic_Gross
# 0                   False               False
# 1                   False               False
# 2                   False               False
# ...

# %%
print(f'Are there any duplicates?\n{data.duplicated().values.any()}')
print(f'There are {len(data[data.duplicated()])} duplicates')
data.duplicated()
# Out:
# Are there any duplicates?
# False
# There are 0 duplicates
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 5386    False
# 5387    False
# 5388    False
# 5389    False
# 5390    False
# Length: 5391, dtype: bool

# %%
data.head()
# Out:
#    Rank Release_Date                     Movie_Title USD_Production_Budget  \
# 0  5293     8/2/1915           The Birth of a Nation              $110,000
# 1  5140     5/9/1916                     Intolerance              $385,907
# 2  5230   12/24/1916    20,000 Leagues Under the Sea              $200,000
# 3  5299    9/17/1920  Over the Hill to the Poorhouse              $100,000
# 4  5222     1/1/1925                  The Big Parade              $245,000
#
#   USD_Worldwide_Gross USD_Domestic_Gross
# 0         $11,000,000        $10,000,000
# 1                  $0                 $0
# 2          $8,000,000         $8,000,000
# 3          $3,000,000         $3,000,000
# 4         $22,000,000        $11,000,000

# %%
data.tail()
# Out:
#       Rank Release_Date                     Movie_Title USD_Production_Budget  \
# 5386  2950    10/8/2018                             Meg           $15,000,000
# 5387   126   12/18/2018                         Aquaman          $160,000,000
# 5388    96   12/31/2020                     Singularity          $175,000,000
# 5389  1119   12/31/2020          Hannibal the Conqueror           $50,000,000
# 5390  2517   12/31/2020  Story of Bonnie and Clyde, The           $20,000,000
#
#      USD_Worldwide_Gross USD_Domestic_Gross
# 5386                  $0                 $0
# 5387                  $0                 $0
# 5388                  $0                 $0
# 5389                  $0                 $0
# 5390                  $0                 $0

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5391 entries, 0 to 5390
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rank                   5391 non-null   int64
#  1   Release_Date           5391 non-null   object
#  2   Movie_Title            5391 non-null   object
#  3   USD_Production_Budget  5391 non-null   object
#  4   USD_Worldwide_Gross    5391 non-null   object
#  5   USD_Domestic_Gross     5391 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 252.8+ KB

# %%
data.sample()
# Out:
#       Rank Release_Date       Movie_Title USD_Production_Budget  \
# 2816  4824    12/5/2006  Dead Man's Shoes            $1,125,000
#
#      USD_Worldwide_Gross USD_Domestic_Gross
# 2816            $414,736             $6,408

# %%
for i in data.columns:
    print(type(i))
# Out:
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>
# <class 'str'>

# %% [markdown]
# ### Data Type Conversions

# %% [markdown]
# **Challenge**: Convert the `USD_Production_Budget`, `USD_Worldwide_Gross`, and `USD_Domestic_Gross` columns to a numeric format by removing `$` signs and `,`.
# <br>
# <br>
# Note that *domestic* in this context refers to the United States.

# %%
data.USD_Production_Budget = data.USD_Production_Budget.astype(str).str.replace("$", "")
data.USD_Worldwide_Gross = data.USD_Worldwide_Gross.astype(str).str.replace("$", "")
data.USD_Domestic_Gross = data.USD_Domestic_Gross.astype(str).str.replace("$", "")

data.USD_Production_Budget = data.USD_Production_Budget.astype(str).str.replace(",", "")
data.USD_Worldwide_Gross = data.USD_Worldwide_Gross.astype(str).str.replace(",", "")
data.USD_Domestic_Gross = data.USD_Domestic_Gross.astype(str).str.replace(",", "")

data.USD_Production_Budget = pd.to_numeric(data.USD_Production_Budget)
data.USD_Worldwide_Gross = pd.to_numeric(data.USD_Worldwide_Gross)
data.USD_Domestic_Gross = pd.to_numeric(data.USD_Domestic_Gross)

data.head()

# -------------==========--------------OR-------------==========--------------
# chars_to_remove = [',', '$']
# columns_to_clean = ['USD_Production_Budget', 
#                     'USD_Worldwide_Gross',
#                     'USD_Domestic_Gross']

# for col in columns_to_clean:
#     for char in chars_to_remove:
#         # Replace each character with an empty string
#         data[col] = data[col].astype(str).str.replace(char, "")
#     # Convert column to a numeric data type
#     data[col] = pd.to_numeric(data[col])
# Out:
# C:\Users\Deleo Anangfac\AppData\Local\Temp\ipykernel_32300\1054821360.py:1: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data.USD_Production_Budget = data.USD_Production_Budget.astype(str).str.replace("$", "")
# C:\Users\Deleo Anangfac\AppData\Local\Temp\ipykernel_32300\1054821360.py:2: FutureWarning: The default value of regex will change from True to False in a future version. In addition, single character regular expressions will *not* be treated as literal strings when regex=True.
#   data.USD_Worldwide_Gross = data.USD_Worldwide_Gross.astype(str).str.replace("$", "")
# ...

# %% [markdown]
# **Challenge**: Convert the `Release_Date` column to a Pandas Datetime type.

# %%
data.Release_Date = pd.to_datetime(data.Release_Date)
data.head()
# Out:
#    Rank Release_Date                     Movie_Title  USD_Production_Budget  \
# 0  5293   1915-08-02           The Birth of a Nation                 110000
# 1  5140   1916-05-09                     Intolerance                 385907
# 2  5230   1916-12-24    20,000 Leagues Under the Sea                 200000
# 3  5299   1920-09-17  Over the Hill to the Poorhouse                 100000
# 4  5222   1925-01-01                  The Big Parade                 245000
#
#    USD_Worldwide_Gross  USD_Domestic_Gross
# 0             11000000            10000000
# 1                    0                   0
# 2              8000000             8000000
# 3              3000000             3000000
# 4             22000000            11000000

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5391 entries, 0 to 5390
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Rank                   5391 non-null   int64
#  1   Release_Date           5391 non-null   datetime64[ns]
#  2   Movie_Title            5391 non-null   object
#  3   USD_Production_Budget  5391 non-null   int64
#  4   USD_Worldwide_Gross    5391 non-null   int64
#  5   USD_Domestic_Gross     5391 non-null   int64
# dtypes: datetime64[ns](1), int64(4), object(1)
# memory usage: 252.8+ KB

# %%
data.describe()
# Out:
#           Rank  USD_Production_Budget  USD_Worldwide_Gross  USD_Domestic_Gross
# count 5,391.00               5,391.00             5,391.00            5,391.00
# mean  2,696.00          31,113,737.58        88,855,421.96       41,235,519.44
# std   1,556.39          40,523,796.88       168,457,757.00       66,029,346.27
# min       1.00               1,100.00                 0.00                0.00
# 25%   1,348.50           5,000,000.00         3,865,206.00        1,330,901.50
# 50%   2,696.00          17,000,000.00        27,450,453.00       17,192,205.00
# 75%   4,043.50          40,000,000.00        96,454,455.00       52,343,687.00
# max   5,391.00         425,000,000.00     2,783,918,982.00      936,662,225.00

# %% [markdown]
# ### Descriptive Statistics

# %% [markdown]
# **Challenge**:
#
# 1. What is the average production budget of the films in the data set?
# 2. What is the average worldwide gross revenue of films?
# 3. What were the minimums for worldwide and domestic revenue?
# 4. Are the bottom 25% of films actually profitable or do they lose money?
# 5. What are the highest production budget and highest worldwide gross revenue of any film?
# 6. How much revenue did the lowest and highest budget films make?

# %%
# Everything below can be gotten from a single line of code
data.describe()
# Out:
#           Rank  USD_Production_Budget  USD_Worldwide_Gross  USD_Domestic_Gross
# count 5,391.00               5,391.00             5,391.00            5,391.00
# mean  2,696.00          31,113,737.58        88,855,421.96       41,235,519.44
# std   1,556.39          40,523,796.88       168,457,757.00       66,029,346.27
# min       1.00               1,100.00                 0.00                0.00
# 25%   1,348.50           5,000,000.00         3,865,206.00        1,330,901.50
# 50%   2,696.00          17,000,000.00        27,450,453.00       17,192,205.00
# 75%   4,043.50          40,000,000.00        96,454,455.00       52,343,687.00
# max   5,391.00         425,000,000.00     2,783,918,982.00      936,662,225.00

# %%
print(f'The average production budget is ${round(data.USD_Production_Budget.mean(), 2)}')
# Out:
# The average production budget is $31113737.58

# %%
print(f'The average worldwide gross is ${round(data.USD_Worldwide_Gross.mean(), 2)}')
# Out:
# The average worldwide gross is $88855421.96

# %%
print(f'The minimum worldwide revenue is ${data.USD_Worldwide_Gross.min()} and domestic revenue is ${data.USD_Domestic_Gross.min()}')
# Out:
# The minimum worldwide revenue is $0 and domestic revenue is $0

# %%
data.describe()
# Then identify 25%
# Out:
#           Rank  USD_Production_Budget  USD_Worldwide_Gross  USD_Domestic_Gross
# count 5,391.00               5,391.00             5,391.00            5,391.00
# mean  2,696.00          31,113,737.58        88,855,421.96       41,235,519.44
# std   1,556.39          40,523,796.88       168,457,757.00       66,029,346.27
# min       1.00               1,100.00                 0.00                0.00
# 25%   1,348.50           5,000,000.00         3,865,206.00        1,330,901.50
# 50%   2,696.00          17,000,000.00        27,450,453.00       17,192,205.00
# 75%   4,043.50          40,000,000.00        96,454,455.00       52,343,687.00
# max   5,391.00         425,000,000.00     2,783,918,982.00      936,662,225.00

# %%
print(f'The maximum production budget is ${data.USD_Production_Budget.max()} and worldwide budget is ${data.USD_Worldwide_Gross.max()}')
# Out:
# The maximum production budget is $425000000 and worldwide budget is $2783918982

# %%
check = data.USD_Worldwide_Gross.subtract(data.USD_Production_Budget)
print(f'Lowest budget is ${check.min()} and highest budget is ${check.max()}')
# Out:
# Lowest budget is $-175000000 and highest budget is $2358918982

# %% [markdown]
# # Investigating the Zero Revenue Films

# %% [markdown]
# **Challenge** How many films grossed $0 domestically (i.e., in the United States)? What were the highest budget films that grossed nothing?

# %%
zerodom = data[data.USD_Domestic_Gross==0]
print(f'There are {zerodom.shape[0]} films that grossed $O domestically')
zerodom[["Movie_Title","USD_Domestic_Gross"]]
# Out:
# There are 512 films that grossed $O domestically
#                            Movie_Title  USD_Domestic_Gross
# 1                          Intolerance                   0
# 6                                Wings                   0
# 8                        Hell's Angels                   0
# 17    Charge of the Light Brigade, The                   0
# 27             How Green Was My Valley                   0
# ...                                ...                 ...
# 5386                               Meg                   0
# 5387                           Aquaman                   0
# 5388                       Singularity                   0
# 5389            Hannibal the Conqueror                   0
# 5390    Story of Bonnie and Clyde, The                   0
#
# [512 rows x 2 columns]

# %%
zerodom.sort_values("USD_Production_Budget", ascending=False)
# Out:
#       Rank Release_Date                         Movie_Title  \
# 5388    96   2020-12-31                         Singularity
# 5387   126   2018-12-18                             Aquaman
# 5384   321   2018-09-03                   A Wrinkle in Time
# 5385   366   2018-10-08                      Amusement Park
# 5090   556   2015-12-31  Don Gato, el inicio de la pandilla
# ...    ...          ...                                 ...
# 4787  5371   2014-12-31                Stories of Our Lives
# 3056  5374   2007-12-31                         Tin Can Man
# 4907  5381   2015-05-19                    Family Motocross
# 5006  5389   2015-09-29             Signed Sealed Delivered
# 5007  5390   2015-09-29                A Plague So Pleasant
#
#       USD_Production_Budget  USD_Worldwide_Gross  USD_Domestic_Gross
# 5388              175000000                    0                   0
# 5387              160000000                    0                   0
# ...

# %% [markdown]
# **Challenge**: How many films grossed $0 worldwide? What are the highest budget films that had no revenue internationally?

# %%
zerowor = data[data.USD_Worldwide_Gross==0]
print(f'There are {zerowor.shape[0]} films that grossed $O worldwide')
zerowor[["Movie_Title","USD_Worldwide_Gross"]]
# Out:
# There are 357 films that grossed $O worldwide
#                            Movie_Title  USD_Worldwide_Gross
# 1                          Intolerance                    0
# 6                                Wings                    0
# 8                        Hell's Angels                    0
# 17    Charge of the Light Brigade, The                    0
# 27             How Green Was My Valley                    0
# ...                                ...                  ...
# 5386                               Meg                    0
# 5387                           Aquaman                    0
# 5388                       Singularity                    0
# 5389            Hannibal the Conqueror                    0
# 5390    Story of Bonnie and Clyde, The                    0
#
# [357 rows x 2 columns]

# %%
zerowor.sort_values("USD_Production_Budget", ascending=False)
# Out:
#       Rank Release_Date              Movie_Title  USD_Production_Budget  \
# 5388    96   2020-12-31              Singularity              175000000
# 5387   126   2018-12-18                  Aquaman              160000000
# 5384   321   2018-09-03        A Wrinkle in Time              103000000
# 5385   366   2018-10-08           Amusement Park              100000000
# 5058   880   2015-11-12         The Ridiculous 6               60000000
# ...    ...          ...                      ...                    ...
# 4787  5371   2014-12-31     Stories of Our Lives                  15000
# 3056  5374   2007-12-31              Tin Can Man                  12000
# 4907  5381   2015-05-19         Family Motocross                  10000
# 5006  5389   2015-09-29  Signed Sealed Delivered                   5000
# 5007  5390   2015-09-29     A Plague So Pleasant                   1400
#
#       USD_Worldwide_Gross  USD_Domestic_Gross
# 5388                    0                   0
# ...

# %% [markdown]
# ### Filtering on Multiple Conditions

# %%
international_releases=data.loc[(data.USD_Domestic_Gross == 0) & 
                                (data.USD_Worldwide_Gross != 0)]

# %%
print(f"Number of international release is {len(international_releases)}")
international_releases.head()
# Out:
# Number of international release is 155
#       Rank Release_Date              Movie_Title  USD_Production_Budget  \
# 71    4310   1956-02-16                 Carousel                3380000
# 1579  5087   2001-02-11  Everything Put Together                 500000
# 1744  3695   2001-12-31                 The Hole                7500000
# 2155  4236   2003-12-31                  Nothing                4000000
# 2203  2513   2004-03-31                The Touch               20000000
#
#       USD_Worldwide_Gross  USD_Domestic_Gross
# 71                   3220                   0
# 1579                 7890                   0
# 1744             10834406                   0
# 2155                63180                   0
# 2203              5918742                   0

# %% [markdown]
# **Challenge**: Use the [`.query()` function](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.query.html) to accomplish the same thing. Create a subset for international releases that had some worldwide gross revenue, but made zero revenue in the United States.
#
# Hint: This time you'll have to use the `and` keyword.

# %%
inter = data.query('USD_Domestic_Gross==0 and USD_Worldwide_Gross!=0')
inter.head()
# Out:
#       Rank Release_Date              Movie_Title  USD_Production_Budget  \
# 71    4310   1956-02-16                 Carousel                3380000
# 1579  5087   2001-02-11  Everything Put Together                 500000
# 1744  3695   2001-12-31                 The Hole                7500000
# 2155  4236   2003-12-31                  Nothing                4000000
# 2203  2513   2004-03-31                The Touch               20000000
#
#       USD_Worldwide_Gross  USD_Domestic_Gross
# 71                   3220                   0
# 1579                 7890                   0
# 1744             10834406                   0
# 2155                63180                   0
# 2203              5918742                   0

# %% [markdown]
# ### Unreleased Films
#
# **Challenge**:
# * Identify which films were not released yet as of the time of data collection (May 1st, 2018).
# * How many films are included in the dataset that have not yet had a chance to be screened in the box office?
# * Create another DataFrame called data_clean that does not include these films.

# %%
# Date of Data Collection
scrape_date = pd.Timestamp('2018-5-1')

# %%
notrelease = data[data.Release_Date >= scrape_date]
notrelease
# Out:
#       Rank Release_Date                     Movie_Title  \
# 5384   321   2018-09-03               A Wrinkle in Time
# 5385   366   2018-10-08                  Amusement Park
# 5386  2950   2018-10-08                             Meg
# 5387   126   2018-12-18                         Aquaman
# 5388    96   2020-12-31                     Singularity
# 5389  1119   2020-12-31          Hannibal the Conqueror
# 5390  2517   2020-12-31  Story of Bonnie and Clyde, The
#
#       USD_Production_Budget  USD_Worldwide_Gross  USD_Domestic_Gross
# 5384              103000000                    0                   0
# 5385              100000000                    0                   0
# 5386               15000000                    0                   0
# 5387              160000000                    0                   0
# 5388              175000000                    0                   0
# 5389               50000000                    0                   0
# ...

# %%
print(f'There are {len(notrelease)} films that have not yet had the chance to screened in the box office ')
# Out:
# There are 7 films that have not yet had the chance to screened in the box office

# %%
data_clean = data.drop(notrelease.index)
print(data.shape)
print(data_clean.shape)
data_clean.head()
# Out:
# (5391, 6)
# (5384, 6)
#    Rank Release_Date                     Movie_Title  USD_Production_Budget  \
# 0  5293   1915-08-02           The Birth of a Nation                 110000
# 1  5140   1916-05-09                     Intolerance                 385907
# 2  5230   1916-12-24    20,000 Leagues Under the Sea                 200000
# 3  5299   1920-09-17  Over the Hill to the Poorhouse                 100000
# 4  5222   1925-01-01                  The Big Parade                 245000
#
#    USD_Worldwide_Gross  USD_Domestic_Gross
# 0             11000000            10000000
# 1                    0                   0
# 2              8000000             8000000
# 3              3000000             3000000
# 4             22000000            11000000

# %% [markdown]
# ### Films that Lost Money
#
# **Challenge**:
# What is the percentage of films where the production costs exceeded the worldwide gross revenue?

# %%
money_gain = data_clean.loc[(data_clean.USD_Worldwide_Gross)>(data_clean.USD_Production_Budget)]
money_lose = data_clean.loc[(data_clean.USD_Worldwide_Gross)<=(data_clean.USD_Production_Budget)]

# %%
print(f"The is {round(len(money_gain)*100/len(data_clean),1)}% who gain in film production")
print(f"The is {round(len(money_lose)*100/len(data_clean),1)}% who lose in film production")
# Out:
# The is 62.7% who gain in film production
# The is 37.3% who lose in film production

# %% [markdown]
# # Seaborn for Data Viz: Bubble Charts

# %%
sns.scatterplot(data=data_clean, x='USD_Production_Budget', y='USD_Worldwide_Gross')
# Out:
# <AxesSubplot: xlabel='USD_Production_Budget', ylabel='USD_Worldwide_Gross'>

# %%
plt.figure(figsize=(8,4), dpi=250)
sns.scatterplot(data=data_clean, x='USD_Production_Budget', y='USD_Worldwide_Gross')
plt.show()

# %%
plt.figure(figsize=(8,4), dpi=250)

ax = sns.scatterplot(data=data_clean, x='USD_Production_Budget', y='USD_Worldwide_Gross')
ax.set(ylim=(0, 3000000000),
        xlim=(0, 450000000),
        ylabel='Revenue in $ billions',
        xlabel='Budget in $100 millions')
plt.show()

# %% [markdown]
# ### Plotting Movie Releases over Time
#
# **Challenge**: Try to create the following Bubble Chart:
#
# <img src=https://i.imgur.com/8fUn9T6.png>

# %%
plt.figure(figsize=(8,4), dpi=250)
ax = sns.scatterplot(data=data_clean,
                x='USD_Production_Budget',
                y='USD_Worldwide_Gross',
                hue='USD_Worldwide_Gross',
                size='USD_Worldwide_Gross')
ax.set(ylim=(0,3000000000),
        xlim=(0,450000000),
        ylabel="Revenue in $ billions",
        xlabel="budget in $100 millions")
plt.show()

# %%
plt.figure(figsize=(8,4), dpi=250)
with sns.axes_style('whitegrid'):
    ax = sns.scatterplot(data=data_clean,
                    x='USD_Production_Budget',
                    y='USD_Worldwide_Gross',
                    hue='USD_Worldwide_Gross',
                    size='USD_Worldwide_Gross')
    ax.set(ylim=(0,3000000000),
            xlim=(0,450000000),
            ylabel="Revenue in $ billions",
            xlabel="budget in $100 millions")

# %%
plt.figure(figsize=(8,4), dpi=250)
with sns.axes_style("darkgrid"):
    ax = sns.scatterplot(data=data_clean,
                        x="Release_Date",
                        y="USD_Production_Budget",
                        hue="USD_Worldwide_Gross",
                        size="USD_Worldwide_Gross")
    ax.set(xlim=(data_clean.Release_Date.min(), data_clean.Release_Date.max()),
        ylim=(0, 450000000),
        xlabel="Years",
        ylabel="budget in $100 millions")

# %% [markdown]
# # Converting Years to Decades Trick
#
# **Challenge**: Create a column in `data_clean` that has the decade of the release.
#
# <img src=https://i.imgur.com/0VEfagw.png width=650>
#
# Here's how:
# 1. Create a [`DatetimeIndex` object](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DatetimeIndex.html) from the Release_Date column.
# 2. Grab all the years from the `DatetimeIndex` object using the `.year` property.
# <img src=https://i.imgur.com/5m06Ach.png width=650>
# 3. Use floor division `//` to convert the year data to the decades of the films.
# 4. Add the decades as a `Decade` column to the `data_clean` DataFrame.

# %%
years=pd.DatetimeIndex(data_clean.Release_Date)
data_clean["Decade"]=(years.year//10)*10
data_clean.head()
# Out:
#    Rank Release_Date                     Movie_Title  USD_Production_Budget  \
# 0  5293   1915-08-02           The Birth of a Nation                 110000
# 1  5140   1916-05-09                     Intolerance                 385907
# 2  5230   1916-12-24    20,000 Leagues Under the Sea                 200000
# 3  5299   1920-09-17  Over the Hill to the Poorhouse                 100000
# 4  5222   1925-01-01                  The Big Parade                 245000
#
#    USD_Worldwide_Gross  USD_Domestic_Gross  Decade
# 0             11000000            10000000    1910
# 1                    0                   0    1910
# 2              8000000             8000000    1910
# 3              3000000             3000000    1920
# 4             22000000            11000000    1920

# %% [markdown]
# ### Separate the "old" (before 1969) and "New" (1970s onwards) Films
#
# **Challenge**: Create two new DataFrames: `old_films` and `new_films`
# * `old_films` should include all the films before 1969 (up to and including 1969)
# * `new_films` should include all the films from 1970 onwards
# * How many films were released prior to 1970?
# * What was the most expensive film made prior to 1970?

# %%
old_films = data_clean.loc[data_clean.Decade<=1960]
old_films
# Out:
#      Rank Release_Date                         Movie_Title  \
# 0    5293   1915-08-02               The Birth of a Nation
# 1    5140   1916-05-09                         Intolerance
# 2    5230   1916-12-24        20,000 Leagues Under the Sea
# 3    5299   1920-09-17      Over the Hill to the Poorhouse
# 4    5222   1925-01-01                      The Big Parade
# ..    ...          ...                                 ...
# 148  2375   1969-10-15                    Paint Your Wagon
# 149  3831   1969-10-24  Butch Cassidy and the Sundance Kid
# 150  2175   1969-12-16                        Hello, Dolly
# 151  3613   1969-12-18     On Her Majesty's Secret Service
# 152  4195   1969-12-19                               Topaz
#
#      USD_Production_Budget  USD_Worldwide_Gross  USD_Domestic_Gross  Decade
# 0                   110000             11000000            10000000    1910
# 1                   385907                    0                   0    1910
# ...

# %%
old_films.describe()
# Out:
#           Rank  USD_Production_Budget  USD_Worldwide_Gross  \
# count   153.00                 153.00               153.00
# mean  4,274.77           4,611,297.65        30,419,634.38
# std     742.14           5,713,648.85        54,931,828.93
# min   1,253.00             100,000.00                 0.00
# 25%   3,973.00           1,250,000.00         5,273,000.00
# 50%   4,434.00           2,900,000.00        10,000,000.00
# 75%   4,785.00           5,000,000.00        33,208,099.00
# max   5,299.00          42,000,000.00       390,525,192.00
#
#        USD_Domestic_Gross   Decade
# count              153.00   153.00
# mean        22,389,473.87 1,949.15
# std         32,641,752.41    12.72
# min                  0.00 1,910.00
# 25%          5,000,000.00 1,940.00
# 50%         10,000,000.00 1,950.00
# 75%         28,350,000.00 1,960.00
# max        198,680,470.00 1,960.00

# %%
new_films = data_clean.loc[data_clean.Decade>1960]
new_films
# Out:
#       Rank Release_Date                       Movie_Title  \
# 153   2159   1970-01-01                          Waterloo
# 154   2270   1970-01-01                      Darling Lili
# 155   3136   1970-01-01                            Patton
# 156   3277   1970-01-01                The Molly Maguires
# 157   4265   1970-01-01                           M*A*S*H
# ...    ...          ...                               ...
# 5379  1295   2017-10-02            John Wick: Chapter Two
# 5380    70   2017-10-03                Kong: Skull Island
# 5381    94   2017-12-05  King Arthur: Legend of the Sword
# 5382  1254   2017-12-05                          Snatched
# 5383  2521   2017-12-31                The Thousand Miles
#
#       USD_Production_Budget  USD_Worldwide_Gross  USD_Domestic_Gross  Decade
# 153                25000000                    0                   0    1970
# 154                22000000              5000000             5000000    1970
# ...

# %%
new_films.describe()
# Out:
#           Rank  USD_Production_Budget  USD_Worldwide_Gross  \
# count 5,231.00               5,231.00             5,231.00
# mean  2,652.00          31,811,437.73        90,683,497.56
# std   1,549.33          40,758,580.67       170,424,978.36
# min       1.00               1,100.00                 0.00
# 25%   1,314.50           5,000,000.00         3,831,677.00
# 50%   2,629.00          18,000,000.00        28,544,120.00
# 75%   3,967.50          40,000,000.00        98,777,000.00
# max   5,391.00         425,000,000.00     2,783,918,982.00
#
#        USD_Domestic_Gross   Decade
# count            5,231.00 5,231.00
# mean        41,841,922.35 2,000.19
# std         66,702,734.68     9.58
# min                  0.00 1,970.00
# 25%          1,252,581.00 2,000.00
# 50%         17,510,118.00 2,000.00
# 75%         53,301,583.00 2,010.00
# max        936,662,225.00 2,010.00

# %% [markdown]
# # Seaborn Regression Plots

# %%
sns.regplot(data=old_films, x='USD_Production_Budget', y='USD_Worldwide_Gross')
# Out:
# <AxesSubplot: xlabel='USD_Production_Budget', ylabel='USD_Worldwide_Gross'>

# %% [markdown]
# **Challenge**: Use Seaborn's `.regplot()` to show the scatter plot and linear regression line against the `new_films`.
# <br>
# <br>
# Style the chart
#
# * Put the chart on a `'darkgrid'`.
# * Set limits on the axes so that they don't show negative values.
# * Label the axes on the plot "Revenue in \$ billions" and "Budget in \$ millions".
# * Provide HEX colour codes for the plot and the regression line. Make the dots dark blue (#2f4b7c) and the line orange (#ff7c43).
#
# Interpret the chart
#
# * Do our data points for the new films align better or worse with the linear regression than for our older films?
# * Roughly how much would a film with a budget of $150 million make according to the regression line?

# %%
plt.figure(figsize=(8,4), dpi=250)
with sns.axes_style("whitegrid"):
    ax = sns.regplot(data=old_films,
                    x='USD_Production_Budget',
                    y='USD_Worldwide_Gross',
                    scatter_kws = {'alpha': 0.2},
                    line_kws = {'color': 'r'})
    ax.set(xlim=(0,43000000),
            ylim=(0,400000000),
            xlabel="budget in $100 millions",
            ylabel="Revenue in $ billions")

# %%
# Plotting of the new films
plt.figure(figsize=(8,4), dpi=250)
with sns.axes_style("darkgrid"):
    ax = sns.regplot(data=new_films,
                    x='USD_Production_Budget',
                    y='USD_Worldwide_Gross',
                    color="#ff7c43",
                    scatter_kws = {'alpha': 0.5},
                    line_kws = {'color': 'g'})
    ax.set(xlim=(0,450000000),
            ylim=(0,3000000000),
            xlabel="budget in $100 millions",
            ylabel="Revenue in $ billions")

# %% [markdown]
# # Run Your Own Regression with scikit-learn
#
# $$ REV \hat ENUE = \theta _0 + \theta _1 BUDGET$$

# %%
regression = LinearRegression()

# %%
# Explanatory Variable(s) or Feature(s)
X = pd.DataFrame(new_films, columns=['USD_Production_Budget'])

# Response Variable or Target
y = pd.DataFrame(new_films, columns=['USD_Worldwide_Gross'])

# %%
# Find the best-fit line
regression.fit(X, y)
# Out:
# LinearRegression()

# %%
# Theta Zero or Y initial
regression.intercept_
# Out:
# array([-8650768.00661042])

# %%
# Theta One or Gradient or Slope
regression.coef_
# Out:
# array([[3.12259592]])

# %%
# R-squared
pn=regression.score(X, y)
pn
# Out:
# 0.5577032617720403

# %%
print(f"The is a {round((pn*100),2)}% profit of new age films")
# Out:
# The is a 55.77% profit of new age films

# %% [markdown]
# **Challenge**: Run a linear regression for the `old_films`. Calculate the intercept, slope and r-squared. How much of the variance in movie revenue does the linear model explain in this case?

# %%
X = pd.DataFrame(old_films, columns=['USD_Production_Budget'])
y = pd.DataFrame(old_films, columns=['USD_Worldwide_Gross'])

# %%
regression_old = LinearRegression()

# %%
regression_old.fit(X,y)
# Out:
# LinearRegression()

# %%
regression_old.intercept_[0]
# Out:
# 22821538.635080386

# %%
regression_old.coef_[0,0]
# Out:
# 1.6477131440107315

# %%
po=regression_old.score(X,y)
po
# Out:
# 0.02937258620576877

# %%
print(f"The is a {round((po*100),2)}% profit of old age films")
# Out:
# The is a 2.94% profit of old age films

# %% [markdown]
# # Use Your Model to Make a Prediction
#
# We just estimated the slope and intercept! Remember that our Linear Model has the following form:
#
# $$ REV \hat ENUE = \theta _0 + \theta _1 BUDGET$$
#
# **Challenge**:  How much global revenue does our model estimate for a film with a budget of $350 million?

# %%
# For the new films
theta0=regression.intercept_[0]
theta1=regression.coef_[0,0]
ans=theta0 + (theta1*350000000)
print(f"The revenue of $350 million is ${round(ans,2)}")
# Out:
# The revenue of $350 million is $1084257803.06

# %%
# For the old films
theta0=regression_old.intercept_[0]
theta1=regression_old.coef_[0,0]
ans=theta0 + (theta1*350000000)
print(f"The revenue of $350 million is ${round(ans,2)}")
# Out:
# The revenue of $350 million is $599521139.04
